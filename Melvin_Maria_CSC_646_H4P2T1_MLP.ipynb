# %% [markdown]
# ### Build a DNN for ECG Signal Classification (5 classes)  - Pytorch
# This is the implementation of an MLP for classifying the ECG signals. <br>
# Your task is to design new DNNs for ECG signal classification <br>
# You can use this file as a template

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as nnF
from torch.utils.data import DataLoader as torch_dataloader
from torch.utils.data import Dataset as torch_dataset
import torch.optim as optim

# %% [markdown]
# ## The Neural Network: MLP  (Replace this with your CNN and rename the file)

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear1 = nn.Linear(in_features=187, out_features=256) 
        self.linear2 = nn.Linear(in_features=256, out_features=128)
        self.linear3 = nn.Linear(in_features=128, out_features=64)
        self.norm3 = nn.LayerNorm(64)
        self.linear4 = nn.Linear(in_features=64, out_features=32)
        self.norm4 = nn.LayerNorm(32)
        self.linear5 = nn.Linear(in_features=32, out_features=16)
        self.norm5 = nn.LayerNorm(16)
        self.linear6 = nn.Linear(in_features=16, out_features=5)
        
        self.avg1=torch.nn.AvgPool1d(kernel_size=2,stride=2)
        self.avg2=torch.nn.AvgPool1d(kernel_size=2,stride=2)
        self.avg3=torch.nn.AvgPool1d(kernel_size=2,stride=2)
        
    def forward(self, x):
        #print("x", x.shape)  it should be (batch_size, 187)
        x1=self.linear1(x)
        #print("x1", x1.shape)
        x1a=nnF.relu(x1)
        #print("x1a", x1a.shape)
        x2=self.linear2(x1a)
        #print("x2", x2.shape)
        x2a=nnF.relu(x2)+self.avg1(x1a)
        #print("x2a", x2a.shape)
        x3=self.linear3(x2a)
        #print("x3", x3.shape)
        x3a=nnF.relu(self.norm3(x3))+self.avg2(x2a)
        #print("x3a", x3a.shape)
        x4=self.linear4(x3a)
        #print("x4", x4.shape)
        x4a=nnF.relu(self.norm4(x4))+self.avg3(x3a)
        x5=self.linear5(x4a)
        #print("x5", x5.shape)
        x5a=nnF.relu(self.norm5(x5))
        z=self.linear6(x5a)
        #print(z.shape)
        #y=nnF.softmax(z, dim=1)
        return z

# %%
#debug your network here
#make sure it works for one single input sample
model=Net()
x=torch.rand(1,187) # (2,187) batch_size =2 if using BatchNorm
#x=torch.rand(10,1,187) if network is CNN
z=model(x)
print(z)
# Out:
# tensor([[ 0.6269,  0.4461,  0.8654, -0.4506, -0.5358]],
#        grad_fn=<AddmmBackward0>)

# %%
def save_checkpoint(filename, z, optimizer, result, epoch):
    torch.save({'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'result':result},
               filename)
    print('saved:', filename)

# %%
def cal_accuracy(confusion):
    #input: confusion is the confusion matrix
    #output: acc is the standard classification accuracy
    M=confusion.copy().astype('float32')
    acc = M.diagonal().sum()/M.sum()    
    sens=np.zeros(M.shape[0])
    prec=np.zeros(M.shape[0]) 
    for n in range(0, M.shape[0]):
        TP=M[n,n]
        FN=np.sum(M[n,:])-TP
        FP=np.sum(M[:,n])-TP
        sens[n]=TP/(TP+FN)
        prec[n]=TP/(TP+FP)       
    return acc, sens, prec

# %% [markdown]
# ## The function to train the model

# %%
def train(model, device, optimizer, dataloader, epoch):    
    model.train()#set model to training mode
    loss_train=0
    acc_train =0 
    sample_count=0
    for batch_idx, (X, Y) in enumerate(dataloader):
        X, Y = X.to(device), Y.to(device)
        optimizer.zero_grad()#clear grad of each parameter
        Z = model(X)#forward pass
        loss = nnF.cross_entropy(Z, Y)
        loss.backward()#backward pass
        optimizer.step()#update parameters
        loss_train+=loss.item()
        #do not need softmax
        Yp = Z.data.max(dim=1)[1]  # get the index of the max               
        acc_train+= torch.sum(Yp==Y).item()
        sample_count+=X.size(0)
        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{:.0f}%]\tLoss: {:.6f}'.format(
                    epoch, 100. * batch_idx / len(dataloader), loss.item()))
    loss_train/=len(dataloader)
    #due to upsampling, len(dataloader.dataset) != sample_count
    #acc_train/=len(dataloader.dataset) 
    acc_train/=sample_count    
    return loss_train, acc_train

# %% [markdown]
# ## The Function to test the model

# %%
def test(model, device, dataloader):
    model.eval()#set model to evaluation mode
    acc_test =0
    confusion=np.zeros((5,5))
    with torch.no_grad(): # tell Pytorch not to build graph in the with section
        for batch_idx, (X, Y) in enumerate(dataloader):
            X, Y = X.to(device), Y.to(device)
            Z = model(X)#forward pass
            #do not need softmax
            Yp = Z.data.max(dim=1)[1]  # get the index of the max 
            acc_test+= torch.sum(Yp==Y).item()
            for i in range(0, 5):
                for j in range(0, 5):
                    confusion[i,j]+=torch.sum((Y==i)&(Yp==j)).item()
    acc, sens, prec=cal_accuracy(confusion)
    return acc, (confusion, sens, prec)

# %% [markdown]
# ## Load data and create dataloaders

# %%
class MyDataset(torch_dataset):
    def __init__(self, X, Y):
        self.X=X
        self.Y=Y
    def __len__(self):
        #return the number of data points
        return self.X.shape[0]
    def __getitem__(self, idx):        
        #we can use DatasetName[idx] to get a data point (x,y) with index idx
        x=torch.tensor(self.X[idx], dtype=torch.float32)
        y=torch.tensor(self.Y[idx], dtype=torch.int64)
        #x=x.reshape(1,-1) if network is CNN
        return x, y

# %%
import pandas as pd
X=pd.read_csv('ECG_dataX.csv')
Y=pd.read_csv('ECG_dataY.csv')

# %%
#convert dataframe to numpy array
X=X.values
X.shape
# Out:
# (3841, 187)

# %%
#convert dataframe to numpy array
Y=Y.values
Y.shape
# Out:
# (3841, 1)

# %%
#reshape Y into a 1D array
Y=Y.reshape(-1)
Y.shape
# Out:
# (3841,)

# %%
plt.hist(Y)
# Out:
# (array([800.,   0., 800.,   0.,   0., 800.,   0., 641.,   0., 800.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
fs=125  # sampling frequency
Ts=1/fs # sampling interval
N=187 # the number of timepoints
Duration=N*Ts # duration of a signal
t=np.linspace(0, Duration-Ts, N) # array of timepoints
fig, ax = plt.subplots(5,1,constrained_layout=True, figsize=(10,10))
for c in range(0, 5):   
    for n in range(0, 3):
        idx=np.random.randint(0,10)
        ax[c].plot(t, X[Y==c][idx])        
        ax[c].set_xlabel('time t [seconds]', fontsize=16)
        ax[c].set_ylabel('amplitude', fontsize=16)
    ax[c].set_title('class '+str(c), fontsize=16)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.1, random_state=0)

# %%
dataset_train=MyDataset(X_train, Y_train)
dataset_val=MyDataset(X_val, Y_val)
dataset_test=MyDataset(X_test, Y_test)

# %%
loader_train = torch_dataloader(dataset_train, batch_size=128, shuffle=True, num_workers=0)
loader_val = torch_dataloader(dataset_val, batch_size=128, shuffle=False, num_workers=0) 
loader_test = torch_dataloader(dataset_test, batch_size=128, shuffle=False, num_workers=0)

# %% [markdown]
# ## Create a model, and start the traning-validation-testing process

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = Net()
model.to(device)
x = dataset_train[0][0]
x = x.view(1, 187).to(device) # change it to x.view(1, 1, 187).to(device) for CNN
#z = model(x)

# %%
y_hat=nnF.softmax(z, dim=1)
y_hat
# Out:
# tensor([[0.2662, 0.2221, 0.3379, 0.0906, 0.0832]], grad_fn=<SoftmaxBackward0>)

# %% [markdown]
# use stochastic gradient descent as the optimization method

# %%
optimizer = optim.SGD(model.parameters(), lr=0.001, weight_decay=1e-4)

# %%
loss_train_list=[]
acc_train_list=[]
acc_val_list=[]
acc_test_list=[]
epoch_save=-1

# %% [markdown]
# train/val/test over many epochs

# %%
for epoch in range(epoch_save+1, 600): #change 100 to a larger number if necessary
    #-------- training --------------------------------
    loss_train, acc_train =train(model, device, optimizer, loader_train, epoch)    
    loss_train_list.append(loss_train)
    acc_train_list.append(acc_train)
    print('epoch', epoch, 'training loss:', loss_train, 'acc:', acc_train)
    #-------- validation --------------------------------
    acc_val, other_val = test(model, device, loader_val)
    acc_val_list.append(acc_val)
    print('epoch', epoch, 'validation acc:', acc_val)
    #-------- testing --------------------------------
    acc_test, other_test = test(model, device, loader_test)
    acc_test_list.append(acc_test)
    print('epoch', epoch, 'test acc:', acc_test)   
    #--------save model-------------------------
    result = (loss_train_list, acc_train_list, 
              acc_val_list, other_val)
    save_checkpoint('ECG_MLP_Pytorch_epoch'+str(epoch)+'.pt', model, optimizer, result, epoch)
    epoch_save=epoch
# Out:
# Train Epoch: 0 [0%]	Loss: 1.727291
# epoch 0 training loss: 1.6862351894378662 acc: 0.21128798842257598
# epoch 0 validation acc: 0.19480519
# epoch 0 test acc: 0.1989597
# saved: ECG_MLP_Pytorch_epoch0.pt
# Train Epoch: 1 [0%]	Loss: 1.660035
# C:\Users\Mestr\AppData\Local\Temp\ipykernel_192696\3076453557.py:13: RuntimeWarning: invalid value encountered in float_scalars
#   prec[n]=TP/(TP+FP)
# epoch 1 training loss: 1.6580369039015337 acc: 0.21273516642547033
# epoch 1 validation acc: 0.19480519
# epoch 1 test acc: 0.1989597
# saved: ECG_MLP_Pytorch_epoch1.pt
# Train Epoch: 2 [0%]	Loss: 1.660416
# epoch 2 training loss: 1.6342558860778809 acc: 0.21309696092619393
# epoch 2 validation acc: 0.20779221
# epoch 2 test acc: 0.1976593
# saved: ECG_MLP_Pytorch_epoch2.pt
# Train Epoch: 3 [0%]	Loss: 1.604201
# epoch 3 training loss: 1.6130807562307878 acc: 0.22178002894356005
# epoch 3 validation acc: 0.23051947
# epoch 3 test acc: 0.21326397
# saved: ECG_MLP_Pytorch_epoch3.pt
# Train Epoch: 4 [0%]	Loss: 1.592277
# epoch 4 training loss: 1.59249624339017 acc: 0.2362518089725036
# epoch 593 validation acc: 0.85064936
# epoch 593 test acc: 0.88686603
# saved: ECG_MLP_Pytorch_epoch593.pt
# Train Epoch: 594 [0%]	Loss: 0.051233
# epoch 594 training loss: 0.06791838258504868 acc: 0.9913169319826338
# epoch 594 validation acc: 0.85714287
# epoch 594 test acc: 0.8829649
# saved: ECG_MLP_Pytorch_epoch594.pt
# Train Epoch: 595 [0%]	Loss: 0.082993
# epoch 595 training loss: 0.06886995245109905 acc: 0.9916787264833574
# epoch 595 validation acc: 0.8538961
# epoch 595 test acc: 0.8855657
# saved: ECG_MLP_Pytorch_epoch595.pt
# Train Epoch: 596 [0%]	Loss: 0.068738
# epoch 596 training loss: 0.06952586041932757 acc: 0.9909551374819102
# epoch 596 validation acc: 0.8474026
# epoch 596 test acc: 0.87776333
# saved: ECG_MLP_Pytorch_epoch596.pt
# Train Epoch: 597 [0%]	Loss: 0.095224
# epoch 597 training loss: 0.06985092010687698 acc: 0.9909551374819102
# epoch 597 validation acc: 0.85714287
# epoch 597 test acc: 0.87256175
# saved: ECG_MLP_Pytorch_epoch597.pt
# Train Epoch: 598 [0%]	Loss: 0.062344
# epoch 598 training loss: 0.07183744402771647 acc: 0.9902315484804631
# epoch 598 validation acc: 0.85064936
# epoch 598 test acc: 0.86996096
# saved: ECG_MLP_Pytorch_epoch598.pt
# Train Epoch: 599 [0%]	Loss: 0.066591
# epoch 599 training loss: 0.06659763204780492 acc: 0.993849493487699
# epoch 599 validation acc: 0.8474026
# epoch 599 test acc: 0.8816645
# saved: ECG_MLP_Pytorch_epoch599.pt

# %%
fig, ax = plt.subplots(1, 2, figsize=(12,6))
ax[0].set_title('loss v.s. epoch',fontsize=16)
ax[0].plot(loss_train_list, '-b', label='training loss')
ax[0].set_xlabel('epoch',fontsize=16)
ax[0].legend(fontsize=16)
ax[0].grid(True)
ax[1].set_title('accuracy v.s. epoch',fontsize=16)
ax[1].plot(acc_train_list, '-b', label='training accuracy')
ax[1].plot(acc_val_list, '-g', label='validation accuracy')
ax[1].plot(acc_test_list, '-r', label='test accuracy')
ax[1].set_xlabel('epoch',fontsize=16)
ax[1].legend(fontsize=16)
ax[1].grid(True)

# %% [markdown]
# load the best model

# %%
best_epoch=np.argmax(acc_val_list)
best_epoch
# Out:
# 492

# %%
checkpoint=torch.load('ECG_MLP_Pytorch_epoch'+str(best_epoch)+'.pt')
model=Net()
model.load_state_dict(checkpoint['model_state_dict'])
model.to(device);
model.eval();

# %%
acc, (confusion, sens, prec) = test(model, device, loader_test)
print('Accuracy (average)', acc)
print('Sensitivity', sens)
print('Precision', prec)
print('Confusion \n', confusion)
# Out:
# Accuracy (average) 0.8803641
# Sensitivity [0.77272725 0.8831169  0.91780823 0.91803277 0.92982459]
# Precision [0.84472048 0.82926828 0.89333332 0.90322578 0.93529409]
# Confusion
#  [[136.  23.   6.   4.   7.]
#  [ 11. 136.   4.   2.   1.]
#  [  2.   1. 134.   6.   3.]
#  [  6.   0.   4. 112.   0.]
#  [  6.   4.   2.   0. 159.]]
